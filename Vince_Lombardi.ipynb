# %%
# Initial imports
import pandas as pd
from sklearn import tree
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# Needed for decision tree visualization
import pydotplus
from IPython.display import Image

# %% [markdown]
# ## Loading and Preprocessing Loans Encoded Data
#
# Load the `sba_loans_encoded.csv` in a pandas DataFrame called `df_loans`.

# %%
# Loading data
df_loans = pd.read_csv("resources/cleaned_data/crime_2020.csv")
df_loans.head()
# Out:
#        DR_NO               Date Rptd    DATE OCC  TIME OCC  AREA   AREA NAME  \
# 0  190326475  03/01/2020 12:00:00 AM  2020-03-01      2130     7    Wilshire
# 1  200106753  02/09/2020 12:00:00 AM  2020-02-08      1800     1     Central
# 2  200320258  11/11/2020 12:00:00 AM  2020-11-04      1700     3   Southwest
# 3  200907217  05/10/2023 12:00:00 AM  2020-03-10      2037     9    Van Nuys
# 4  200412582  09/09/2020 12:00:00 AM  2020-09-09       630     4  Hollenbeck
#
#    Rpt Dist No  Part 1-2  Crm Cd                               Crm Cd Desc  \
# 0          784         1     510                          VEHICLE - STOLEN
# 1          182         1     330                     BURGLARY FROM VEHICLE
# 2          356         1     480                             BIKE - STOLEN
# 3          964         1     343  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)
# 4          413         1     510                          VEHICLE - STOLEN
#
#    ... Crm Cd 1  Crm Cd 2 Crm Cd 3 Crm Cd 4  \
# 0  ...    510.0     998.0      NaN      NaN
# 1  ...    330.0     998.0      NaN      NaN
# 2  ...    480.0       NaN      NaN      NaN
# 3  ...    343.0       NaN      NaN      NaN
# 4  ...    510.0       NaN      NaN      NaN
#
#                                    LOCATION Cross Street      LAT       LON  \
# 0   1900 S  LONGWOOD                     AV          NaN  34.0375 -118.3506
# 1   1000 S  FLOWER                       ST          NaN  34.0444 -118.2628
# 2   1400 W  37TH                         ST          NaN  34.0210 -118.3002
# 3  14000    RIVERSIDE                    DR          NaN  34.1576 -118.4387
# 4                          200 E  AVENUE 28          NaN  34.0820 -118.2130
#
#        crime_timestamp  Year
# 0  2020-03-01 21:30:00  2020
# 1  2020-02-08 18:00:00  2020
# 2  2020-11-04 17:00:00  2020
# 3  2020-03-10 20:37:00  2020
# 4  2020-09-09 06:30:00  2020
#
# [5 rows x 30 columns]

# %%
df_loans = df_loans[['TIME OCC', 'AREA', 'Part 1-2', 'Rpt Dist No', 'LAT', 'LON']]

# %% [markdown]
# Define the features set, by copying the `df_loans` DataFrame and dropping the `Default` column.

# %%
# Define features set
X = df_loans.copy()
X.drop("Part 1-2", axis=1, inplace=True)
X.head()
# Out:
#    TIME OCC  AREA  Rpt Dist No      LAT       LON
# 0      2130     7          784  34.0375 -118.3506
# 1      1800     1          182  34.0444 -118.2628
# 2      1700     3          356  34.0210 -118.3002
# 3      2037     9          964  34.1576 -118.4387
# 4       630     4          413  34.0820 -118.2130

# %% [markdown]
# Create the target vector by assigning the values of the `Default` column from the `df_loans` DataFrame.

# %%
# Define target vector
y = df_loans["Part 1-2"].values.reshape(-1, 1)
y[:5]
# Out:
# array([[1],
#        [1],
#        [1],
#        [1],
#        [1]])

# %% [markdown]
# Split the data into training and testing sets.

# %%
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %% [markdown]
# Use the `StandardScaler` to scale the features data, remember that only `X_train` and `X_testing` DataFrames should be scaled.

# %%
# Create the StandardScaler instance
scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
X_scaler = scaler.fit(X_train)

# %%
# Scale the training data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Fitting the Decision Tree Model
#
# Once data is scaled, create a decision tree instance and train it with the training data (`X_train_scaled` and `y_train`).

# %%
# Create the decision tree classifier instance
model = tree.DecisionTreeClassifier()

# %%
# Fit the model
model = model.fit(X_train_scaled, y_train)

# %% [markdown]
# ## Making Predictions Using the Tree Model
#
# Validate the trained model, by predicting fraudulent loan applications using the testing data (`X_test_scaled`).

# %%
# Making predictions using the testing data
predictions = model.predict(X_test_scaled)

# %% [markdown]
# ## Model Evaluation
#
# Evaluate model's results, by using `sklearn` to calculate the confusion matrix, the accuracy score and to generate the classification report.

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0        18183        10834
# Actual 1        10919        10016
# Accuracy Score : 0.5645219410634209
# Classification Report
#               precision    recall  f1-score   support
#
#            1       0.62      0.63      0.63     29017
#            2       0.48      0.48      0.48     20935
#
#     accuracy                           0.56     49952
#    macro avg       0.55      0.55      0.55     49952
# weighted avg       0.56      0.56      0.56     49952

# %% [markdown]
# ## Visualizing the Decision Tree
#
# In this section, you should create a visual representation of the decision tree using `pydotplus`. Show the graph on the notebook, and also save it in `PDF` and `PNG` formats.

# %%
# Create DOT data
dot_data = tree.export_graphviz(
    model, out_file=None, feature_names=X.columns, class_names=["0", "1"], filled=True
)

# Draw graph
graph = pydotplus.graph_from_dot_data(dot_data)

# Show graph
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 7
#       2 dot_data = tree.export_graphviz(
#       3     model, out_file=None, feature_names=X.columns, class_names=["0", "1"], filled=True
#       4 )
#       6 # Draw graph
# ----> 7 graph = pydotplus.graph_from_dot_data(dot_data)
#       9 # Show graph
#      10 Image(graph.create_png())
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pydotplus/graphviz.py:302, in graph_from_dot_data(data)
#     294 def graph_from_dot_data(data):
#     295     """Load graph as defined by data in DOT format.
#     296
#     297     The data is assumed to be in DOT format. It will
#     298     be parsed and a Dot class will be returned,
#     299     representing the graph.
#     300     """
# --> 302     return parser.parse_dot_data(data)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pydotplus/parser.py:558, in parse_dot_data(data)
#     555 if pyparsing_version >= '1.2':
#     556     graphparser.parseWithTabs()
# --> 558 tokens = graphparser.parseString(data)
#     560 if len(tokens) == 1:
#     561     return tokens[0]
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/util.py:376, in replaced_by_pep8.<locals>._inner(self, *args, **kwargs)
#     371 @wraps(fn)
#     372 def _inner(self, *args, **kwargs):
#     373     # warnings.warn(
#     374     #     f"Deprecated - use {fn.__name__}", DeprecationWarning, stacklevel=2
#     375     # )
# --> 376     return fn(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:1204, in ParserElement.parse_string(self, instring, parse_all, parseAll)
#    1202     instring = instring.expandtabs()
#    1203 try:
# -> 1204     loc, tokens = self._parse(instring, 0)
#    1205     if parseAll:
#    1206         loc = self.preParse(instring, loc)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:5077, in _MultipleMatch.parseImpl(self, instring, loc, do_actions)
#    5075 if check_ender:
#    5076     try_not_ender(instring, loc)
# -> 5077 loc, tokens = self_expr_parse(instring, loc, do_actions)
#    5078 try:
#    5079     hasIgnoreExprs = not not self.ignoreExprs
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:4152, in And.parseImpl(self, instring, loc, do_actions)
#    4148             raise ParseSyntaxException(
#    4149                 instring, len(instring), self.errmsg, self
#    4150             )
#    4151     else:
# -> 4152         loc, exprtokens = e._parse(instring, loc, do_actions)
#    4153     resultlist += exprtokens
#    4154 return loc, resultlist
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:4650, in ParseElementEnhance.parseImpl(self, instring, loc, do_actions)
#    4647     raise ParseException(instring, loc, "No expression defined", self)
#    4649 try:
# -> 4650     return self.expr._parse(instring, loc, do_actions, callPreParse=False)
#    4651 except ParseSyntaxException:
#    4652     raise
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:4152, in And.parseImpl(self, instring, loc, do_actions)
#    4148             raise ParseSyntaxException(
#    4149                 instring, len(instring), self.errmsg, self
#    4150             )
#    4151     else:
# -> 4152         loc, exprtokens = e._parse(instring, loc, do_actions)
#    4153     resultlist += exprtokens
#    4154 return loc, resultlist
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:5312, in Opt.parseImpl(self, instring, loc, do_actions)
#    5310 self_expr = self.expr
#    5311 try:
# -> 5312     loc, tokens = self_expr._parse(
#    5313         instring, loc, do_actions, callPreParse=False
#    5314     )
#    5315 except (ParseException, IndexError):
#    5316     default_value = self.defaultValue
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:5607, in Forward.parseImpl(self, instring, loc, do_actions)
#    5602     warnings.warn(
#    5603         "Forward expression was never assigned a value, will not parse any input",
#    5604         stacklevel=stacklevel,
#    5605     )
#    5606 if not ParserElement._left_recursion_enabled:
# -> 5607     return super().parseImpl(instring, loc, do_actions)
#    5608 # ## Bounded Recursion algorithm ##
#    5609 # Recursion only needs to be processed at ``Forward`` elements, since they are
#    5610 # the only ones that can actually refer to themselves. The general idea is
#    (...)
#    5625 # we expand using `do_actions=False` and only run `do_actions=True` if the next
#    5626 # recursion level is acceptable.
#    5627 with ParserElement.recursion_lock:
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:4650, in ParseElementEnhance.parseImpl(self, instring, loc, do_actions)
#    4647     raise ParseException(instring, loc, "No expression defined", self)
#    4649 try:
# -> 4650     return self.expr._parse(instring, loc, do_actions, callPreParse=False)
#    4651 except ParseSyntaxException:
#    4652     raise
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:5087, in _MultipleMatch.parseImpl(self, instring, loc, do_actions)
#    5085         else:
#    5086             preloc = loc
# -> 5087         loc, tmptokens = self_expr_parse(instring, preloc, do_actions)
#    5088         tokens += tmptokens
#    5089 except (ParseException, IndexError):
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:4130, in And.parseImpl(self, instring, loc, do_actions)
#    4127 def parseImpl(self, instring, loc, do_actions=True):
#    4128     # pass False as callPreParse arg to _parse for first element, since we already
#    4129     # pre-parsed the string as part of our And pre-parsing
# -> 4130     loc, resultlist = self.exprs[0]._parse(
#    4131         instring, loc, do_actions, callPreParse=False
#    4132     )
#    4133     errorStop = False
#    4134     for e in self.exprs[1:]:
#    4135         # if isinstance(e, And._ErrorStop):
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:4381, in MatchFirst.parseImpl(self, instring, loc, do_actions)
#    4379 for e in self.exprs:
#    4380     try:
# -> 4381         return e._parse(instring, loc, do_actions)
#    4382     except ParseFatalException as pfe:
#    4383         pfe.__traceback__ = None
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:4130, in And.parseImpl(self, instring, loc, do_actions)
#    4127 def parseImpl(self, instring, loc, do_actions=True):
#    4128     # pass False as callPreParse arg to _parse for first element, since we already
#    4129     # pre-parsed the string as part of our And pre-parsing
# -> 4130     loc, resultlist = self.exprs[0]._parse(
#    4131         instring, loc, do_actions, callPreParse=False
#    4132     )
#    4133     errorStop = False
#    4134     for e in self.exprs[1:]:
#    4135         # if isinstance(e, And._ErrorStop):
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:5607, in Forward.parseImpl(self, instring, loc, do_actions)
#    5602     warnings.warn(
#    5603         "Forward expression was never assigned a value, will not parse any input",
#    5604         stacklevel=stacklevel,
#    5605     )
#    5606 if not ParserElement._left_recursion_enabled:
# -> 5607     return super().parseImpl(instring, loc, do_actions)
#    5608 # ## Bounded Recursion algorithm ##
#    5609 # Recursion only needs to be processed at ``Forward`` elements, since they are
#    5610 # the only ones that can actually refer to themselves. The general idea is
#    (...)
#    5625 # we expand using `do_actions=False` and only run `do_actions=True` if the next
#    5626 # recursion level is acceptable.
#    5627 with ParserElement.recursion_lock:
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:4650, in ParseElementEnhance.parseImpl(self, instring, loc, do_actions)
#    4647     raise ParseException(instring, loc, "No expression defined", self)
#    4649 try:
# -> 4650     return self.expr._parse(instring, loc, do_actions, callPreParse=False)
#    4651 except ParseSyntaxException:
#    4652     raise
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:4650, in ParseElementEnhance.parseImpl(self, instring, loc, do_actions)
#    4647     raise ParseException(instring, loc, "No expression defined", self)
#    4649 try:
# -> 4650     return self.expr._parse(instring, loc, do_actions, callPreParse=False)
#    4651 except ParseSyntaxException:
#    4652     raise
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:4381, in MatchFirst.parseImpl(self, instring, loc, do_actions)
#    4379 for e in self.exprs:
#    4380     try:
# -> 4381         return e._parse(instring, loc, do_actions)
#    4382     except ParseFatalException as pfe:
#    4383         pfe.__traceback__ = None
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:4152, in And.parseImpl(self, instring, loc, do_actions)
#    4148             raise ParseSyntaxException(
#    4149                 instring, len(instring), self.errmsg, self
#    4150             )
#    4151     else:
# -> 4152         loc, exprtokens = e._parse(instring, loc, do_actions)
#    4153     resultlist += exprtokens
#    4154 return loc, resultlist
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:5312, in Opt.parseImpl(self, instring, loc, do_actions)
#    5310 self_expr = self.expr
#    5311 try:
# -> 5312     loc, tokens = self_expr._parse(
#    5313         instring, loc, do_actions, callPreParse=False
#    5314     )
#    5315 except (ParseException, IndexError):
#    5316     default_value = self.defaultValue
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:4381, in MatchFirst.parseImpl(self, instring, loc, do_actions)
#    4379 for e in self.exprs:
#    4380     try:
# -> 4381         return e._parse(instring, loc, do_actions)
#    4382     except ParseFatalException as pfe:
#    4383         pfe.__traceback__ = None
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:4650, in ParseElementEnhance.parseImpl(self, instring, loc, do_actions)
#    4647     raise ParseException(instring, loc, "No expression defined", self)
#    4649 try:
# -> 4650     return self.expr._parse(instring, loc, do_actions, callPreParse=False)
#    4651 except ParseSyntaxException:
#    4652     raise
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:4130, in And.parseImpl(self, instring, loc, do_actions)
#    4127 def parseImpl(self, instring, loc, do_actions=True):
#    4128     # pass False as callPreParse arg to _parse for first element, since we already
#    4129     # pre-parsed the string as part of our And pre-parsing
# -> 4130     loc, resultlist = self.exprs[0]._parse(
#    4131         instring, loc, do_actions, callPreParse=False
#    4132     )
#    4133     errorStop = False
#    4134     for e in self.exprs[1:]:
#    4135         # if isinstance(e, And._ErrorStop):
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:4381, in MatchFirst.parseImpl(self, instring, loc, do_actions)
#    4379 for e in self.exprs:
#    4380     try:
# -> 4381         return e._parse(instring, loc, do_actions)
#    4382     except ParseFatalException as pfe:
#    4383         pfe.__traceback__ = None
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:844, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     842 else:
#     843     if callPreParse and self.callPreparse:
# --> 844         pre_loc = self.preParse(instring, loc)
#     845     else:
#     846         pre_loc = loc
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:793, in ParserElement.preParse(self, instring, loc)
#     791 def preParse(self, instring: str, loc: int) -> int:
#     792     if self.ignoreExprs:
# --> 793         loc = self._skipIgnorables(instring, loc)
#     795     if self.skipWhitespace:
#     796         instrlen = len(instring)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:781, in ParserElement._skipIgnorables(self, instring, loc)
#     779 try:
#     780     while 1:
# --> 781         loc, dummy = ignore_fn(instring, loc)
#     782         exprsFound = True
#     783 except ParseException:
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:850, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     848 if self.mayIndexError or pre_loc >= len_instring:
#     849     try:
# --> 850         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     851     except IndexError:
#     852         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:4650, in ParseElementEnhance.parseImpl(self, instring, loc, do_actions)
#    4647     raise ParseException(instring, loc, "No expression defined", self)
#    4649 try:
# -> 4650     return self.expr._parse(instring, loc, do_actions, callPreParse=False)
#    4651 except ParseSyntaxException:
#    4652     raise
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pyparsing/core.py:810, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     807     return tokenlist
#     809 # @profile
# --> 810 def _parseNoCache(
#     811     self, instring, loc, do_actions=True, callPreParse=True
#     812 ) -> tuple[int, ParseResults]:
#     813     debugging = self.debug  # and do_actions)
#     814     len_instring = len(instring)
#
# KeyboardInterrupt:

# %%
# When saving the image, Path() is not used because graph.write_<file_type>() must take a string object

# Saving the tree as PDF
file_path = "../Resources/transactions_tree.pdf"
graph.write_pdf(file_path)

# Saving the tree as PNG
file_path = "../Resources/transactions_tree.png"
graph.write_png(file_path)
# Out:
# True

# %% [markdown]
# ## Analysis Question
#
# Finally, analyze the model's evaluation results and answer the following question.
#
# * Would you trust in this model to deploy a loans application approval solution in a bank?
#
#  * **Sample Answer:** After observing the results, the accuracy seems to be good enought to start exploring this kind of algorithms in a bank, however, I would prefer to start running a pilot with new data to assess model's reliability.
