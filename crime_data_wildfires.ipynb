# %% [markdown]
# Wildfire Event Catgorization

# %%
#import libraries and dependencies
import pandas as pd
import numpy as np
import os

# %% [markdown]
# Franklin Fire - 12.9.2024-12.18.2024
# 4,037 acres burned

# %%
#read in the data
wildfire_data_2024 = pd.read_csv('resources/cleaned_data/crime_2024.csv')

#display the data
wildfire_data_2024
# Out:
#             DR_NO               Date Rptd    DATE OCC  TIME OCC  AREA  \
# 0       242108414  04/25/2024 12:00:00 AM  2024-04-25      1600    21
# 1       240604934  01/21/2024 12:00:00 AM  2024-01-21      1510     6
# 2       241110315  08/29/2024 12:00:00 AM  2024-08-28      1500    11
# 3       242107187  03/22/2024 12:00:00 AM  2024-03-22      1815    21
# 4       241010884  09/06/2024 12:00:00 AM  2024-09-05      1800    10
# ...           ...                     ...         ...       ...   ...
# 127560  240710284  07/24/2024 12:00:00 AM  2024-07-23      1400     7
# 127561  240104953  01/15/2024 12:00:00 AM  2024-01-15       100     1
# 127562  240410786  10/14/2024 12:00:00 AM  2024-10-11      2330     4
# 127563  240309674  04/24/2024 12:00:00 AM  2024-04-24      1500     3
# 127564  240910892  08/13/2024 12:00:00 AM  2024-08-12      2300     9
#
#           AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0           Topanga         2146         1     420
# ...

# %%
#convert the DATE OCC column to datetime
wildfire_data_2024['DATE OCC'] = pd.to_datetime(wildfire_data_2024['DATE OCC'])

#define the date range for the wildfires
start_date = '2024-12-09'
end_date = '2024-12-25'

#create a new column to flag the wildfires
wildfire_data_2024['Wildfire Event'] = wildfire_data_2024['DATE OCC'].apply(lambda date: '1' if start_date <= date.strftime('%Y-%m-%d') <= end_date else '0')

#write the data into a new csv file
wildfire_data_2024.to_csv('resources/cleaned_data/wildfire_data/crime_2024_wildfire.csv', index=False)

# %% [markdown]
# Oak Fire - 7.19.2023-7.20.2023
# 137 acres burned

# %%
#read in the data
wildfire_data_2023 = pd.read_csv('resources/cleaned_data/crime_2023.csv')

#display the data
wildfire_data_2023
# Out:
#             DR_NO               Date Rptd    DATE OCC  TIME OCC  AREA  \
# 0       230611294  06/17/2023 12:00:00 AM  2023-06-17      1140     6
# 1       230106843  02/12/2023 12:00:00 AM  2023-02-11      1630     1
# 2       231515059  09/19/2023 12:00:00 AM  2023-09-19      1030    15
# 3       230110347  04/11/2023 12:00:00 AM  2023-04-10       816     1
# 4       230618504  12/01/2023 12:00:00 AM  2023-12-01       110     6
# ...           ...                     ...         ...       ...   ...
# 232340  231606525  03/22/2023 12:00:00 AM  2023-03-22      1000    16
# 232341  231716047  10/02/2023 12:00:00 AM  2023-09-25      2200    17
# 232342  230115220  07/02/2023 12:00:00 AM  2023-07-01         1     1
# 232343  230906458  03/05/2023 12:00:00 AM  2023-03-05       900     9
# 232344  230319786  11/10/2023 12:00:00 AM  2023-11-09      2300     3
#
#           AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0         Hollywood          668         1     442
# ...

# %%
#convert the DATE OCC column to datetime
wildfire_data_2023['DATE OCC'] = pd.to_datetime(wildfire_data_2023['DATE OCC'])

#define the date range for the wildfires
start_date = '2023-07-19'
end_date = '2023-08-02'

#create a new column to flag the wildfires
wildfire_data_2023['Wildfire Event'] = wildfire_data_2023['DATE OCC'].apply(lambda date: '1' if start_date <= date.strftime('%Y-%m-%d') <= end_date else '0')

#write the data into a new csv file
wildfire_data_2023.to_csv('resources/cleaned_data/wildfire_data/crime_2023_wildfire.csv', index=False)

# %% [markdown]
# Fairview Fire - 9.5.2022
# 28,098 acres burned

# %%
#read in the data
wildfire_data_2022 = pd.read_csv('resources/cleaned_data/crime_2022.csv')

#display the data
wildfire_data_2022.head()
# Out:
#        DR_NO               Date Rptd    DATE OCC  TIME OCC  AREA AREA NAME  \
# 0  221412417  06/16/2022 12:00:00 AM  2022-06-16       200    14   Pacific
# 1  221311340  05/17/2022 12:00:00 AM  2022-05-17      1205    13    Newton
# 2  222011339  06/20/2022 12:00:00 AM  2022-06-20       100    20   Olympic
# 3  221600628  12/19/2022 12:00:00 AM  2022-12-19      1830    16  Foothill
# 4  220510220  06/15/2022 12:00:00 AM  2022-06-13      1400     5    Harbor
#
#    Rpt Dist No  Part 1-2  Crm Cd       Crm Cd Desc  ... Crm Cd 1  Crm Cd 2  \
# 0         1495         1     510  VEHICLE - STOLEN  ...    510.0       NaN
# 1         1321         1     510  VEHICLE - STOLEN  ...    510.0       NaN
# 2         2023         1     510  VEHICLE - STOLEN  ...    510.0       NaN
# 3         1622         2     890  FAILURE TO YIELD  ...    890.0       NaN
# 4          504         1     510  VEHICLE - STOLEN  ...    510.0       NaN
#
# ...

# %%
#convert the DATE OCC column to a datetime object
wildfire_data_2022['DATE OCC'] = pd.to_datetime(wildfire_data_2022['DATE OCC'])

#define the date range for the wildfires
start_date = '2022-09-05'
end_date = '2022-09-19'

#create a new column to flag the wildfires
wildfire_data_2022['Wildfire Event'] = wildfire_data_2022['DATE OCC'].apply(lambda date: '1' if start_date <= date.strftime('%Y-%m-%d') <= end_date else '0')

#write the data to a new csv file
wildfire_data_2022.to_csv('resources/cleaned_data/wildfire_data/crime_2022_wildfire.csv', index=False)

# %% [markdown]
# Palisades Fire - 5.14.2021
# 1,202 acres burned

# %%
#read in the 2021 data
wildfire_data_2021 = pd.read_csv('resources/cleaned_data/crime_2021.csv')

#display the data
wildfire_data_2021.head()
# Out:
#        DR_NO               Date Rptd    DATE OCC  TIME OCC  AREA  AREA NAME  \
# 0  210712170  08/20/2021 12:00:00 AM  2021-08-19      1500     7   Wilshire
# 1  210508097  04/18/2021 12:00:00 AM  2021-04-17      1100     5     Harbor
# 2  210707858  04/19/2021 12:00:00 AM  2021-04-19      1500     7   Wilshire
# 3  211110481  07/06/2021 12:00:00 AM  2021-06-29      1500    11  Northeast
# 4  210205358  02/05/2021 12:00:00 AM  2021-02-04      1800     2    Rampart
#
#    Rpt Dist No  Part 1-2  Crm Cd       Crm Cd Desc  ... Crm Cd 1  Crm Cd 2  \
# 0          702         1     510  VEHICLE - STOLEN  ...    510.0       NaN
# 1          551         1     510  VEHICLE - STOLEN  ...    510.0       NaN
# 2          706         1     510  VEHICLE - STOLEN  ...    510.0       NaN
# 3         1169         1     510  VEHICLE - STOLEN  ...    510.0       NaN
# 4          215         1     510  VEHICLE - STOLEN  ...    510.0       NaN
#
# ...

# %%
#convert the DATE OCC column to a datetime object
wildfire_data_2021['DATE OCC'] = pd.to_datetime(wildfire_data_2021['DATE OCC'])

#define the date range for the wildfires
start_date_2021 = '2021-05-14'
end_date_2021 = '2021-05-28'

#create a new column to flag the wildfires
wildfire_data_2021['Wildfire Event'] = wildfire_data_2021['DATE OCC'].apply(lambda date: '1' if start_date_2021 <= date.strftime('%Y-%m-%d') <= end_date_2021 else '0')

#write the data to a new csv file
wildfire_data_2021.to_csv('resources/cleaned_data/wildfire_data/crime_2021_wildfire.csv', index=False)

# %% [markdown]
# Bond Fire 12.02.2020-12.10.2020
# 6,686 acres burned

# %%
#read in the 2020 data
wildfire_data_2020 = pd.read_csv('resources/cleaned_data/crime_2020.csv')

#display the data
wildfire_data_2020.head()
# Out:
#        DR_NO               Date Rptd    DATE OCC  TIME OCC  AREA   AREA NAME  \
# 0  190326475  03/01/2020 12:00:00 AM  2020-03-01      2130     7    Wilshire
# 1  200106753  02/09/2020 12:00:00 AM  2020-02-08      1800     1     Central
# 2  200320258  11/11/2020 12:00:00 AM  2020-11-04      1700     3   Southwest
# 3  200907217  05/10/2023 12:00:00 AM  2020-03-10      2037     9    Van Nuys
# 4  200412582  09/09/2020 12:00:00 AM  2020-09-09       630     4  Hollenbeck
#
#    Rpt Dist No  Part 1-2  Crm Cd                               Crm Cd Desc  \
# 0          784         1     510                          VEHICLE - STOLEN
# 1          182         1     330                     BURGLARY FROM VEHICLE
# 2          356         1     480                             BIKE - STOLEN
# 3          964         1     343  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)
# 4          413         1     510                          VEHICLE - STOLEN
#
#    ... Crm Cd 1  Crm Cd 2 Crm Cd 3 Crm Cd 4  \
# ...

# %%
#convert the DATE OCC column to a datetime object
wildfire_data_2020['DATE OCC'] = pd.to_datetime(wildfire_data_2020['DATE OCC'])

#define the date range for the wildfires
start_date_2020 = '2020-12-02'
end_date_2020 = '2020-12-16'

#create a new column to flag the wildfires
wildfire_data_2020['Wildfire Event'] = wildfire_data_2020['DATE OCC'].apply(lambda date: '1' if start_date_2020 <= date.strftime('%Y-%m-%d') <= end_date_2020 else '0')

#write the data to a new csv file
wildfire_data_2020.to_csv('resources/cleaned_data/wildfire_data/crime_2020_wildfire.csv', index=False)
